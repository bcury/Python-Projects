# %% [markdown]
# <a href="https://colab.research.google.com/github/bcury/Python-Projects/blob/main/Gr%C3%A1ficos_MatplotLib_seno_cosseno_linhas_caixas_erros_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
a = np.linspace(0, 4*np.pi, 1000)
b = np.sin(a)

# %%
a
# Out:
# array([ 0.        ,  0.01257895,  0.0251579 ,  0.03773685,  0.0503158 ,
#         0.06289475,  0.0754737 ,  0.08805265,  0.1006316 ,  0.11321055,
#         0.1257895 ,  0.13836845,  0.15094739,  0.16352634,  0.17610529,
#         0.18868424,  0.20126319,  0.21384214,  0.22642109,  0.23900004,
#         0.25157899,  0.26415794,  0.27673689,  0.28931584,  0.30189479,
#         0.31447374,  0.32705269,  0.33963164,  0.35221059,  0.36478954,
#         0.37736849,  0.38994744,  0.40252639,  0.41510534,  0.42768429,
#         0.44026323,  0.45284218,  0.46542113,  0.47800008,  0.49057903,
#         0.50315798,  0.51573693,  0.52831588,  0.54089483,  0.55347378,
#         0.56605273,  0.57863168,  0.59121063,  0.60378958,  0.61636853,
#         0.62894748,  0.64152643,  0.65410538,  0.66668433,  0.67926328,
#         0.69184223,  0.70442118,  0.71700013,  0.72957907,  0.74215802,
#         0.75473697,  0.76731592,  0.77989487,  0.79247382,  0.80505277,
# ...

# %%
b
# Out:
# array([ 0.00000000e+00,  1.25786178e-02,  2.51552454e-02,  3.77278927e-02,
#         5.02945704e-02,  6.28532900e-02,  7.54020646e-02,  8.79389084e-02,
#         1.00461838e-01,  1.12968871e-01,  1.25458030e-01,  1.37927338e-01,
#         1.50374822e-01,  1.62798512e-01,  1.75196443e-01,  1.87566653e-01,
#         1.99907185e-01,  2.12216086e-01,  2.24491409e-01,  2.36731210e-01,
#         2.48933554e-01,  2.61096510e-01,  2.73218154e-01,  2.85296566e-01,
#         2.97329837e-01,  3.09316061e-01,  3.21253344e-01,  3.33139795e-01,
#         3.44973534e-01,  3.56752688e-01,  3.68475395e-01,  3.80139798e-01,
#         3.91744053e-01,  4.03286322e-01,  4.14764781e-01,  4.26177612e-01,
#         4.37523010e-01,  4.48799180e-01,  4.60004337e-01,  4.71136709e-01,
#         4.82194534e-01,  4.93176062e-01,  5.04079556e-01,  5.14903290e-01,
#         5.25645553e-01,  5.36304643e-01,  5.46878875e-01,  5.57366576e-01,
# ...

# %%
fig, ax= plt.subplots()
ax.plot(a,b)
fig.show()

# %%
fig, ax= plt.subplots()
a = np.random.uniform(0, 1, 1000)
b = np.random.uniform(0, 1, 1000)
ax.scatter(a, b)

# %%
fig, ax= plt.subplots()
a = np.arange(15)
b = np.random.uniform(1, 15, 15)
ax.bar(a, b)
# Out:
# <BarContainer object of 15 artists>

# %%
fig, ax= plt.subplots()
c = np.random.uniform(0, 1, (7,7))

ax.imshow(c)

# %%
fig, ax= plt.subplots()
d = np.random.uniform(0, 1, (9,9))

ax.contourf(d)

# %%
fig, ax= plt.subplots()
e = np.random.uniform(0, 1, 4)

ax.pie(e);

# %%
fig, ax= plt.subplots()
z = np.arange(5)
y = np.random.uniform(0, 1, 5)
ax.errorbar( z, y, y/4)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
fig, ax= plt.subplots()

z = np.random.normal(0, 1, (100,5))

ax.boxplot(z);

# %%
fig, ax= plt.subplots()
x = np.linspace(0, 10, 100)
y = np.sin(x)
ax.plot(x, y, color='red');

# %%
fig, ax= plt.subplots()
x = np.linspace(0, 10, 100)
y = np.cos(x)
ax.plot(x, y, color='green');
