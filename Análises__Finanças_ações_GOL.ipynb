# %% [markdown]
# <a href="https://colab.research.google.com/github/bcury/Python-Projects/blob/main/An%C3%A1lises__Finan%C3%A7as_a%C3%A7%C3%B5es_GOL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# !pip install -q yfinance

# %%
import yfinance as yf

# %%
df_gol = yf.download("GOLL4.SA", start='2015-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df_gol
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2015-01-02  14.970000  15.200000  14.610000  14.990000  14.990000   901900
# 2015-01-05  14.900000  15.010000  14.410000  14.850000  14.850000  1272500
# 2015-01-06  14.750000  15.210000  14.650000  15.210000  15.210000  2183500
# 2015-01-07  15.150000  15.330000  14.550000  14.550000  14.550000  1846900
# 2015-01-08  14.410000  14.650000  14.200000  14.270000  14.270000  1569500
# ...               ...        ...        ...        ...        ...      ...
# 2022-01-18  16.620001  16.830000  16.280001  16.379999  16.379999  3633200
# 2022-01-19  16.549999  17.340000  16.320000  16.450001  16.450001  5933500
# 2022-01-20  16.400000  17.379999  16.379999  17.010000  17.010000  6930200
# 2022-01-21  16.840000  17.190001  16.719999  16.969999  16.969999  3017700
# 2022-01-24  17.000000  17.160000  16.049999  16.260000  16.260000  5414500
#
# [1754 rows x 6 columns]

# %%
df_gol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1754 entries, 2015-01-02 to 2022-01-24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1754 non-null   float64
#  1   High       1754 non-null   float64
#  2   Low        1754 non-null   float64
#  3   Close      1754 non-null   float64
#  4   Adj Close  1754 non-null   float64
#  5   Volume     1754 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 95.9 KB

# %%
df_gol.describe()
# Out:
#               Open         High  ...    Adj Close        Volume
# count  1754.000000  1754.000000  ...  1754.000000  1.754000e+03
# mean     15.809629    16.195582  ...    15.771745  5.032113e+06
# std       9.762752     9.942747  ...     9.755381  4.750603e+06
# min       1.160000     1.180000  ...     1.160000  0.000000e+00
# 25%       7.720000     7.880000  ...     7.712500  1.957250e+06
# 50%      14.585000    14.880000  ...    14.580000  3.533200e+06
# 75%      22.200001    22.805000  ...    22.217499  6.389625e+06
# max      43.669998    44.619999  ...    43.790001  4.368050e+07
#
# [8 rows x 6 columns]

# %%
df_gol.head()
# Out:
#              Open   High    Low  Close  Adj Close   Volume
# Date
# 2015-01-02  14.97  15.20  14.61  14.99      14.99   901900
# 2015-01-05  14.90  15.01  14.41  14.85      14.85  1272500
# 2015-01-06  14.75  15.21  14.65  15.21      15.21  2183500
# 2015-01-07  15.15  15.33  14.55  14.55      14.55  1846900
# 2015-01-08  14.41  14.65  14.20  14.27      14.27  1569500

# %%
df_gol.tail()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2022-01-18  16.620001  16.830000  16.280001  16.379999  16.379999  3633200
# 2022-01-19  16.549999  17.340000  16.320000  16.450001  16.450001  5933500
# 2022-01-20  16.400000  17.379999  16.379999  17.010000  17.010000  6930200
# 2022-01-21  16.840000  17.190001  16.719999  16.969999  16.969999  3017700
# 2022-01-24  17.000000  17.160000  16.049999  16.260000  16.260000  5414500

# %%
df_gol['Close'].max(), df_gol['Close'].min()
# Out:
# (43.790000915527344, 1.159999966621399)

# %%
df_gol[df_gol['Close'] > 43.7] #aqui vemos o dia em que ocorreu o maior valor
# Out:
#              Open       High    Low      Close  Adj Close   Volume
# Date
# 2019-08-01  41.25  44.619999  41.25  43.790001  43.790001  6664200

# %%
df_gol[df_gol['Close'] < 1.16] #aqui o menor valor
# Out:
#             Open  High   Low  Close  Adj Close   Volume
# Date
# 2016-01-22   1.2  1.26  1.14   1.16       1.16  3830600

# %% [markdown]
# vamos salvar isso em um arquivo

# %%
df_gol.to_csv('gol.csv')

# %% [markdown]
# agora vamos importar, para nao precisar da API mais

# %%
base_gol = pd.read_csv('/content/gol.csv')

# %%
base_gol.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close   Volume
# 0  2015-01-02  14.97  15.20  14.61  14.99      14.99   901900
# 1  2015-01-05  14.90  15.01  14.41  14.85      14.85  1272500
# 2  2015-01-06  14.75  15.21  14.65  15.21      15.21  2183500
# 3  2015-01-07  15.15  15.33  14.55  14.55      14.55  1846900
# 4  2015-01-08  14.41  14.65  14.20  14.27      14.27  1569500

# %%
sns.histplot(base_gol['Close']);

# %%
sns.histplot(base_gol['Adj Close']);

# %%
sns.boxplot(x = base_gol['Adj Close']);
